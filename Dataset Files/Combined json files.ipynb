# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
up=files.upload()
# Out:
#      <input type="file" id="files-fcefc557-de2e-4c9d-afc5-1398cb022f97" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fcefc557-de2e-4c9d-afc5-1398cb022f97">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
up=files.upload()
# Out:
#      <input type="file" id="files-d29f73b9-bbbb-4b7c-8667-671a429cacb0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d29f73b9-bbbb-4b7c-8667-671a429cacb0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df1 = pd.read_json('phrases_no_exclude_test.jsonl', lines=True)
df1
# Out:
#                                                question  \
# 0     A junior orthopaedic surgery resident is compl...
# 1     A 67-year-old man with transitional cell carci...
# 2     Two weeks after undergoing an emergency cardia...
# 3     A 39-year-old woman is brought to the emergenc...
# 4     A 35-year-old man comes to the physician becau...
# ...                                                 ...
# 1268  A 39-year-old woman presents to the clinic for...
# 1269  A 38-year-old woman comes to the physician bec...
# 1270  A 21-year-old college student comes to the phy...
# 1271  A 19-year-old man is brought to the physician ...
# 1272  A 79-year-old man presents to the office due t...
#
#                                                  answer  \
# 0     Tell the attending that he cannot fail to disc...
# 1                                  Cross-linking of DNA
# 2                              Cholesterol embolization
# 3     Lactose-fermenting, gram-negative rods forming...
# ...

# %%
df = pd.read_json('phrases_no_exclude_train.jsonl', lines=True)
df
# Out:
#                                                 question  \
# 0      A 23-year-old pregnant woman at 22 weeks gesta...
# 1      A 3-month-old baby died suddenly at night whil...
# 2      A mother brings her 3-week-old infant to the p...
# 3      A pulmonary autopsy specimen from a 58-year-ol...
# 4      A 20-year-old woman presents with menorrhagia ...
# ...                                                  ...
# 10173  A 60-year-old man presents to the emergency de...
# 10174  A 45-year-old male with a 15-year history of d...
# 10175  After receiving a positive newborn screening r...
# 10176  A 25-year-old man comes to the office because ...
# 10177  A 26-year-old primigravid woman comes to the e...
#
#                                                   answer  \
# 0                                         Nitrofurantoin
# 1      Placing the infant in a supine position on a f...
# 2           Abnormal migration of ventral pancreatic bud
# ...

# %%
combined_df = pd.concat([df, df1], ignore_index=True)
combined_df
# Out:
#                                                 question  \
# 0      A 23-year-old pregnant woman at 22 weeks gesta...
# 1      A 3-month-old baby died suddenly at night whil...
# 2      A mother brings her 3-week-old infant to the p...
# 3      A pulmonary autopsy specimen from a 58-year-ol...
# 4      A 20-year-old woman presents with menorrhagia ...
# ...                                                  ...
# 11446  A 39-year-old woman presents to the clinic for...
# 11447  A 38-year-old woman comes to the physician bec...
# 11448  A 21-year-old college student comes to the phy...
# 11449  A 19-year-old man is brought to the physician ...
# 11450  A 79-year-old man presents to the office due t...
#
#                                                   answer  \
# 0                                         Nitrofurantoin
# 1      Placing the infant in a supine position on a f...
# 2           Abnormal migration of ventral pancreatic bud
# ...

# %%
combined_df.to_json('combined_file.json', orient='records', lines=True)

# %%
combined_df.to_csv('combined_file.csv', index=False)

# %%
from google.colab import files
files.download('combined_file.csv')
